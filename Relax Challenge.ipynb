# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import and Merge Data

# %%
users = pd.read_csv('takehome_users.csv', encoding='ISO-8859-1')
print(users.shape)
print(users.columns)
users
# Out:
# (12000, 10)
# Index(['object_id', 'creation_time', 'name', 'email', 'creation_source',
#        'last_session_creation_time', 'opted_in_to_mailing_list',
#        'enabled_for_marketing_drip', 'org_id', 'invited_by_user_id'],
#       dtype='object')
#        object_id        creation_time               name  \
# 0              1  2014-04-22 03:53:30     Clausen August
# 1              2  2013-11-15 03:45:04      Poole Matthew
# 2              3  2013-03-19 23:14:52  Bottrill Mitchell
# 3              4  2013-05-21 08:09:28    Clausen Nicklas
# 4              5  2013-01-17 10:14:20          Raw Grace
# ...          ...                  ...                ...
# 11995      11996  2013-09-06 06:14:15       Meier Sophia
# 11996      11997  2013-01-10 18:28:37      Fisher Amelie
# 11997      11998  2014-04-27 12:45:16        Haynes Jake
# 11998      11999  2012-05-31 11:55:59       Faber Annett
# 11999      12000  2014-01-26 08:57:12         Lima Thaís
#
# ...

# %%
engagement = pd.read_csv('takehome_user_engagement.csv')
print(engagement.shape)
engagement
# Out:
# (207917, 3)
#                  time_stamp  user_id  visited
# 0       2014-04-22 03:53:30        1        1
# 1       2013-11-15 03:45:04        2        1
# 2       2013-11-29 03:45:04        2        1
# 3       2013-12-09 03:45:04        2        1
# 4       2013-12-25 03:45:04        2        1
# ...                     ...      ...      ...
# 207912  2013-09-06 06:14:15    11996        1
# 207913  2013-01-15 18:28:37    11997        1
# 207914  2014-04-27 12:45:16    11998        1
# 207915  2012-06-02 11:55:59    11999        1
# 207916  2014-01-26 08:57:12    12000        1
#
# [207917 rows x 3 columns]

# %%
users = users.rename(columns={'object_id': 'user_id'})
users.head()
# Out:
#    user_id        creation_time               name  \
# 0        1  2014-04-22 03:53:30     Clausen August
# 1        2  2013-11-15 03:45:04      Poole Matthew
# 2        3  2013-03-19 23:14:52  Bottrill Mitchell
# 3        4  2013-05-21 08:09:28    Clausen Nicklas
# 4        5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# ...

# %%
users['creation_time']= pd.to_datetime(users['creation_time'])

# %%
users.dtypes
# Out:
# user_id                                int64
# creation_time                 datetime64[ns]
# name                                  object
# email                                 object
# creation_source                       object
# last_session_creation_time           float64
# opted_in_to_mailing_list               int64
# enabled_for_marketing_drip             int64
# org_id                                 int64
# invited_by_user_id                   float64
# dtype: object

# %% [markdown]
# ## Basic EDA

# %%
users.describe()
# Out:
#            user_id  last_session_creation_time  opted_in_to_mailing_list  \
# count  12000.00000                8.823000e+03              12000.000000
# mean    6000.50000                1.379279e+09                  0.249500
# std     3464.24595                1.953116e+07                  0.432742
# min        1.00000                1.338452e+09                  0.000000
# 25%     3000.75000                1.363195e+09                  0.000000
# 50%     6000.50000                1.382888e+09                  0.000000
# 75%     9000.25000                1.398443e+09                  0.000000
# max    12000.00000                1.402067e+09                  1.000000
#
#        enabled_for_marketing_drip        org_id  invited_by_user_id
# count                12000.000000  12000.000000         6417.000000
# mean                     0.149333    141.884583         5962.957145
# std                      0.356432    124.056723         3383.761968
# ...

# %%
engagement.dtypes
# Out:
# time_stamp    object
# user_id        int64
# visited        int64
# dtype: object

# %%
engagement['time_stamp'] = pd.to_datetime(engagement['time_stamp'])
engagement = engagement.set_index('time_stamp')
engagement
# Out:
#                      user_id  visited
# time_stamp
# 2014-04-22 03:53:30        1        1
# 2013-11-15 03:45:04        2        1
# 2013-11-29 03:45:04        2        1
# 2013-12-09 03:45:04        2        1
# 2013-12-25 03:45:04        2        1
# ...                      ...      ...
# 2013-09-06 06:14:15    11996        1
# 2013-01-15 18:28:37    11997        1
# 2014-04-27 12:45:16    11998        1
# 2012-06-02 11:55:59    11999        1
# 2014-01-26 08:57:12    12000        1
#
# [207917 rows x 2 columns]

# %%
print(min(engagement.index))
print(max(engagement.index))
# Out:
# 2012-05-31 08:20:06
# 2014-06-06 14:58:50

# %%
engagement.describe()
# Out:
#              user_id   visited
# count  207917.000000  207917.0
# mean     5913.314197       1.0
# std      3394.941674       0.0
# min         1.000000       1.0
# 25%      3087.000000       1.0
# 50%      5682.000000       1.0
# 75%      8944.000000       1.0
# max     12000.000000       1.0

# %% [markdown]
# ## Calculate total number of visits per user

# %%
visits = engagement.groupby('user_id').sum()
visits.head()
# Out:
#          visited
# user_id
# 1              1
# 2             14
# 3              1
# 4              1
# 5              1

# %%
users = users.merge(visits, how='left', on='user_id')
users.head()
# Out:
#    user_id       creation_time               name                       email  \
# 0        1 2014-04-22 03:53:30     Clausen August    AugustCClausen@yahoo.com
# 1        2 2013-11-15 03:45:04      Poole Matthew      MatthewPoole@gustr.com
# 2        3 2013-03-19 23:14:52  Bottrill Mitchell  MitchellBottrill@gustr.com
# 3        4 2013-05-21 08:09:28    Clausen Nicklas   NicklasSClausen@yahoo.com
# 4        5 2013-01-17 10:14:20          Raw Grace          GraceRaw@yahoo.com
#
#   creation_source  last_session_creation_time  opted_in_to_mailing_list  \
# 0    GUEST_INVITE                1.398139e+09                         1
# 1      ORG_INVITE                1.396238e+09                         0
# 2      ORG_INVITE                1.363735e+09                         0
# 3    GUEST_INVITE                1.369210e+09                         0
# 4    GUEST_INVITE                1.358850e+09                         0
#
# ...

# %%
users['visited'] = users['visited'].fillna(0)
users.head()
# Out:
#    user_id       creation_time               name                       email  \
# 0        1 2014-04-22 03:53:30     Clausen August    AugustCClausen@yahoo.com
# 1        2 2013-11-15 03:45:04      Poole Matthew      MatthewPoole@gustr.com
# 2        3 2013-03-19 23:14:52  Bottrill Mitchell  MitchellBottrill@gustr.com
# 3        4 2013-05-21 08:09:28    Clausen Nicklas   NicklasSClausen@yahoo.com
# 4        5 2013-01-17 10:14:20          Raw Grace          GraceRaw@yahoo.com
#
#   creation_source  last_session_creation_time  opted_in_to_mailing_list  \
# 0    GUEST_INVITE                1.398139e+09                         1
# 1      ORG_INVITE                1.396238e+09                         0
# 2      ORG_INVITE                1.363735e+09                         0
# 3    GUEST_INVITE                1.369210e+09                         0
# 4    GUEST_INVITE                1.358850e+09                         0
#
# ...

# %% [markdown]
# ## Calculate total usage duration from creation to last session

# %%
users['last_session_creation_time'] = pd.to_datetime(users['last_session_creation_time'], unit='s')
users['use_duration'] = users['last_session_creation_time'] - users['creation_time']
users['use_duration'] = users['use_duration'].dt.days
users.head()
# Out:
#    user_id       creation_time               name                       email  \
# 0        1 2014-04-22 03:53:30     Clausen August    AugustCClausen@yahoo.com
# 1        2 2013-11-15 03:45:04      Poole Matthew      MatthewPoole@gustr.com
# 2        3 2013-03-19 23:14:52  Bottrill Mitchell  MitchellBottrill@gustr.com
# 3        4 2013-05-21 08:09:28    Clausen Nicklas   NicklasSClausen@yahoo.com
# 4        5 2013-01-17 10:14:20          Raw Grace          GraceRaw@yahoo.com
#
#   creation_source last_session_creation_time  opted_in_to_mailing_list  \
# 0    GUEST_INVITE        2014-04-22 03:53:30                         1
# 1      ORG_INVITE        2014-03-31 03:45:04                         0
# 2      ORG_INVITE        2013-03-19 23:14:52                         0
# 3    GUEST_INVITE        2013-05-22 08:09:28                         0
# 4    GUEST_INVITE        2013-01-22 10:14:20                         0
#
#    enabled_for_marketing_drip  org_id  invited_by_user_id  visited  \
# ...

# %% [markdown]
# ## Determine if user is considered adopted

# %%
from datetime import timedelta

def feature_adopted(u_id):    
#takes a users from dataframe and returns adopted - More than 3 logins in any 7-day period
    per = 7                                               # Period is 7 days
    df = engagement.loc[engagement['user_id'] == u_id]    # Select this user
    df = df.resample('D').mean().dropna()                 # Resample 
    adopted = 0
    for i in range(len(df)-2):                       #loop over active days till the second to last day
        if df.index[i + 2] - df.index[i] <= timedelta(days=per): # if gap between 3 logins less than period
            adopted = 1
            break
        else: adopted = 0
    return adopted

# %%
users['adopted'] = users['user_id'].apply(feature_adopted)
print(users.shape)
users.head()
# Out:
# (12000, 13)
#    user_id       creation_time               name                       email  \
# 0        1 2014-04-22 03:53:30     Clausen August    AugustCClausen@yahoo.com
# 1        2 2013-11-15 03:45:04      Poole Matthew      MatthewPoole@gustr.com
# 2        3 2013-03-19 23:14:52  Bottrill Mitchell  MitchellBottrill@gustr.com
# 3        4 2013-05-21 08:09:28    Clausen Nicklas   NicklasSClausen@yahoo.com
# 4        5 2013-01-17 10:14:20          Raw Grace          GraceRaw@yahoo.com
#
#   creation_source last_session_creation_time  opted_in_to_mailing_list  \
# 0    GUEST_INVITE        2014-04-22 03:53:30                         1
# 1      ORG_INVITE        2014-03-31 03:45:04                         0
# 2      ORG_INVITE        2013-03-19 23:14:52                         0
# 3    GUEST_INVITE        2013-05-22 08:09:28                         0
# 4    GUEST_INVITE        2013-01-22 10:14:20                         0
#
# ...

# %%
print(sum(users['adopted']))
print((sum(users['adopted'])/len(users['adopted']))*100)
# Out:
# 1656
# 13.8

# %% [markdown]
# ## Model Prep

# %%
df = users.drop(['name','email', 'creation_time', 'last_session_creation_time'], axis = 1)
df['invited_by_user_id'] = df['invited_by_user_id'].fillna(0) 
df['use_duration'] = df['use_duration'].fillna(0)
df.isnull().sum()
# Out:
# user_id                       0
# creation_source               0
# opted_in_to_mailing_list      0
# enabled_for_marketing_drip    0
# org_id                        0
# invited_by_user_id            0
# visited                       0
# use_duration                  0
# adopted                       0
# dtype: int64

# %%
df = pd.get_dummies(df, columns = ['creation_source'])
df.head()
# Out:
#    user_id  opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0        1                         1                           0      11
# 1        2                         0                           0       1
# 2        3                         0                           0      94
# 3        4                         0                           0       1
# 4        5                         0                           0     193
#
#    invited_by_user_id  visited  use_duration  adopted  \
# 0             10803.0      1.0           0.0        0
# 1               316.0     14.0         136.0        1
# 2              1525.0      1.0           0.0        0
# 3              5151.0      1.0           1.0        0
# 4              5240.0      1.0           5.0        0
#
#    creation_source_GUEST_INVITE  creation_source_ORG_INVITE  \
# 0                             1                           0
# 1                             0                           1
# ...

# %% [markdown]
# ## Create Model and evaluation Metrics

# %%
from sklearn.model_selection import train_test_split
X = df.drop('adopted',axis=1)
y = df['adopted']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=74)

# %%
from sklearn.ensemble import RandomForestClassifier

#train and test classifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.99

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score

#print out classification report and confusion matrix
y_pred = rf.predict(X_test)

print(classification_report(y_test, y_pred))

cm= confusion_matrix(y_test,y_pred)
print('confusion matrix:')
print(cm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2591
#            1       0.97      0.95      0.96       409
#
#     accuracy                           0.99      3000
#    macro avg       0.98      0.97      0.98      3000
# weighted avg       0.99      0.99      0.99      3000
#
# confusion matrix:
# [[2581   10]
#  [  20  389]]

# %%
features = pd.DataFrame()
features['coef'] = rf.feature_importances_
features = features.set_index(X.columns)
features.coef.nlargest(15)
# Out:
# visited                               0.579749
# use_duration                          0.354006
# org_id                                0.020921
# user_id                               0.020608
# invited_by_user_id                    0.011876
# opted_in_to_mailing_list              0.002533
# creation_source_PERSONAL_PROJECTS     0.002102
# creation_source_GUEST_INVITE          0.001885
# enabled_for_marketing_drip            0.001877
# creation_source_ORG_INVITE            0.001703
# creation_source_SIGNUP                0.001448
# creation_source_SIGNUP_GOOGLE_AUTH    0.001291
# Name: coef, dtype: float64

# %%
top5 = features.coef.nlargest(5)
sns.barplot(y=top5.index,x=top5.values)
plt.title('Model Feature Importances')
plt.ylabel('Coefficient')
plt.xlabel('Coefficient value')
plt.show()
